# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
# Create client using key from environment
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.chat.completions.create(
    model="gpt-5-nano",  
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! Just checking that you're working."}
    ],
)

print(response.choices[0].message.content)
# Out:
# Hi there! Yes, I’m here and ready to help. What would you like to do today? I can answer questions, draft text, brainstorm ideas, explain topics, help with coding, plan projects, or summarize articles—whatever you need.
